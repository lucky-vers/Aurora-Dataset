# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./NVMP_DATA.csv')

# %%
# Out:
#       Station Code                        Name of Monitoring Location  \
# 0               26           BORE WELL AT KANURUPANCHAYAT, VIJAYAWADA
# 1             1513  BORE WELL AT AUTONAGAR, VIJAYAWADA.( IN THE R/...
# 2             1514  BORE WELL AT AUTONAGAR, VIJAYAWADA.( IN THE R/...
# 3             1516            BOREWELL OF NAVLOKGARDENS, NELLORE TOWN
# 4             1517  BOREWELL NEAR TUNGBHADRA RIVER, MAMIDALAPADU (...
# ...            ...                                                ...
# 1114          4733                   GROUNDWATER AT SUKNAFOREST RANGE
# 1115          4734                 TUBE WELL INSIDE MAHISHADALRAJBARI
# 1116          4735                  TUBE WELL INSIDE MECHEDABUS STAND
# 1117          4736                             TUBE WELL AT OLD DIGHA
# 1118          4737               GROUND WATER AT SHYAMPUR BUDGE BUDGE
#
#           State Name Temp_Min Temp_Max pH_Min pH_Max Conductivity_Min  \
# ...
